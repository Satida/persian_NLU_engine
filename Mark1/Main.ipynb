# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# %cd /content/gdrive/My\ Drive/work_space/Chatbot/NLU/Mark1
# %pip install import_ipynb
import import_ipynb
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/My Drive/work_space/Chatbot/NLU/Mark1
# ...

# %%
# %cd /content/gdrive/My\ Drive/work_space/Chatbot/
# Out:
# /content/gdrive/My Drive/work_space/Chatbot

# %%
# !ls
# !zip -r NLU.zip NLU
# Out:
#   adding: NLU/ (stored 0%)
#   adding: NLU/resources/ (stored 0%)
#   adding: NLU/resources/stopwords.dat (deflated 61%)
#   adding: NLU/resources/lib/ (stored 0%)
#   adding: NLU/resources/lib/libsvm.jar (deflated 6%)
#   adding: NLU/resources/lib/liblinear-1.8.jar (deflated 6%)
#   adding: NLU/resources/lib/log4j.jar (deflated 9%)
#   adding: NLU/resources/chunker.model (deflated 62%)
#   adding: NLU/resources/malt.jar (deflated 7%)
#   adding: NLU/resources/langModel.mco (deflated 0%)
#   adding: NLU/resources/postagger.model (deflated 75%)
#   adding: NLU/Mark1/ (stored 0%)
#   adding: NLU/Mark1/models/ (stored 0%)
#   adding: NLU/Mark1/models/cc.fa.300.bin
#
#
# zip error: Interrupted (aborting)

# %% [markdown]
# #Import NLU Engine :
# -----------------------

# %%
import NLU

# %%
ready_to_train = NLU.Start("en","../dataset")
ready_to_predict = NLU.Train(load_model=False,**ready_to_train)
# Out:
# train Score : 0.9761904761904762

# %%
text = "میخوام درس بینایی ماشن را اخذ کنم و درس اخلاق اشلامی حذف کنم ."

# %%
text ="میخوام درس بینایی ماشن 95125856 را اخذ کنم"

# %%
text ="میخواستم درس ریاضی ۲ روز یکشنبه را حذف کنم"

# %%
text ="اشتباهه"

# %%
result = NLU.Predict(text,**ready_to_predict)
NLU.ShowResult(result)
# Out:
# Intent :  ========================================
# 	 reject_queries
#
# Entities :
# ...
#
# Slots    :
# ...
